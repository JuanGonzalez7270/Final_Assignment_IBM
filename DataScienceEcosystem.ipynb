# %% [markdown]
# ![2%20-%20title.png](attachment:2%20-%20title.png)

# %% [markdown]
# ![3%20-%20intro.png](attachment:3%20-%20intro.png)

# %% [markdown]
# ![4%20-%20dslanguages.png](attachment:4%20-%20dslanguages.png)

# %% [markdown]
# ![5%20-%20dslibraries.png](attachment:5%20-%20dslibraries.png)

# %% [markdown]
# ![6%20-%20dstools.png](attachment:6%20-%20dstools.png)

# %% [markdown]
# ![7%20-%20introarithmetic.png](attachment:7%20-%20introarithmetic.png)

# %% [markdown]
# ![8%20-%20multiplyandaddintegers.png](attachment:8%20-%20multiplyandaddintegers.png)

# %% [markdown]
# Exercise 9 - Create a code cell to convert minutes to hours.

# %% [markdown]
# ![9%20-%20hourstominutes.png](attachment:9%20-%20hourstominutes.png)

# %% [markdown]
# Exercise 10 -Insert a markdown cell to list Objectives.

# %% [markdown]
# ![10%20-%20objetives.png](attachment:10%20-%20objetives.png)

# %% [markdown]
# ![11%20-%20authordetails.png](attachment:11%20-%20authordetails.png)
